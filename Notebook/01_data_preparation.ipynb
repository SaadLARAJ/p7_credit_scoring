# %% [markdown]
# # Notebook 01 – Data preparation & Kaggle kernel adaptation
#
# Objectif: reproduire et adapter le kernel de João Saguiar
# ([LightGBM with simple features](https://www.kaggle.com/code/jsaguiar/lightgbm-with-simple-features/script))
# pour produire des datasets prêts pour l'entraînement local et l'API.

# %% [markdown]
# ## Plan
# 1. Charger les fichiers bruts depuis `Src/Data/`.
# 2. Reproduire les agrégations (bureau, bureau_balance, previous_application, POS, installments, credit card).
# 3. Vérifier la cohérence des features, la distribution de la cible, et gérer les valeurs manquantes.
# 4. Générer les datasets finaux et les sauvegarder (`Src/Prepared/train.parquet`, etc.).
# 5. Journaliser les décisions (commentaires Markdown) pour expliquer les écarts par rapport au kernel Kaggle.

# %%
# Imports de base – à compléter selon vos besoins
import pandas as pd
import numpy as np
from pathlib import Path

DATA_DIR = Path('..') / 'Src' / 'Data'
PREPARED_DIR = Path('..') / 'Src' / 'Prepared'
PREPARED_DIR.mkdir(exist_ok=True, parents=True)

DATA_DIR, PREPARED_DIR

# %% [markdown]
# 👉 *Insérer ici la reproduction détaillée du kernel Kaggle, en gardant
# une cellule Markdown avant chaque bloc pour expliquer l'adaptation locale.*
