# %% [markdown]
# # Notebook 02 – Modélisation, métrique métier et MLflow
#
# Ce notebook exploite les datasets préparés pour entraîner plusieurs modèles
# avec une fonction de coût métier (FN ×10) et suivre toutes les expériences
# dans MLflow.

# %% [markdown]
# ## Étapes
# 1. Charger les jeux de données produit par Notebook 01.
# 2. Définir la métrique métier (coût) + fonction pour optimiser le seuil.
# 3. Configurer MLflow (`mlflow.set_experiment`).
# 4. Évaluer une baseline (logistic regression) puis LightGBM avec GridSearchCV.
# 5. Enregistrer explications globales/locales et pousser le meilleur modèle dans le Model Registry.

# %%
import json
from pathlib import Path
import mlflow
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score

PREPARED_DIR = Path('..') / 'Src' / 'Prepared'
train = pd.read_parquet(PREPARED_DIR / 'train.parquet')
valid = pd.read_parquet(PREPARED_DIR / 'valid.parquet')
test = pd.read_parquet(PREPARED_DIR / 'test.parquet')
train.shape, valid.shape, test.shape

# %% [markdown]
# 👉 *Insérer ici la logique MLflow (start_run, log_params/metrics), la fonction de coût métier,
# le recalibrage du seuil et le SHAP analysis.*
